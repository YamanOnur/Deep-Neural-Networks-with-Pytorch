# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[3.081385 ]
#  [2.9894938]
#  [2.8976026]]
# 1 [[5.7296906]
#  [5.61464  ]
#  [5.49959  ]]
# 2 [[6.6155167]
#  [6.4811974]
#  [6.346878 ]]
# 3 [[13.859846]
#  [13.446357]
#  [13.032867]]

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

for x, y in trainloader:
    print("yhat= ", model(x),"y", y)
# Out:
# yhat=  tensor([[13.8598]], grad_fn=<AddmmBackward0>) y tensor([[0.]])
# yhat=  tensor([[13.4464]], grad_fn=<AddmmBackward0>) y tensor([[9.6413]])
# yhat=  tensor([[13.0329]], grad_fn=<AddmmBackward0>) y tensor([[9.3929]])
# yhat=  tensor([[12.6194]], grad_fn=<AddmmBackward0>) y tensor([[9.1716]])
# yhat=  tensor([[12.2059]], grad_fn=<AddmmBackward0>) y tensor([[8.8276]])
# yhat=  tensor([[11.7924]], grad_fn=<AddmmBackward0>) y tensor([[8.4037]])
# yhat=  tensor([[11.3789]], grad_fn=<AddmmBackward0>) y tensor([[8.3595]])
# yhat=  tensor([[10.9654]], grad_fn=<AddmmBackward0>) y tensor([[7.9693]])
# yhat=  tensor([[10.5519]], grad_fn=<AddmmBackward0>) y tensor([[7.5838]])
# yhat=  tensor([[10.1384]], grad_fn=<AddmmBackward0>) y tensor([[7.4887]])
# yhat=  tensor([[9.7250]], grad_fn=<AddmmBackward0>) y tensor([[7.0017]])
# yhat=  tensor([[9.3115]], grad_fn=<AddmmBackward0>) y tensor([[6.8140]])
# yhat=  tensor([[8.8980]], grad_fn=<AddmmBackward0>) y tensor([[6.4470]])
# yhat=  tensor([[8.4845]], grad_fn=<AddmmBackward0>) y tensor([[6.0929]])
# yhat=  tensor([[8.0710]], grad_fn=<AddmmBackward0>) y tensor([[5.9515]])
# yhat=  tensor([[7.6575]], grad_fn=<AddmmBackward0>) y tensor([[5.3601]])
# yhat=  tensor([[7.2440]], grad_fn=<AddmmBackward0>) y tensor([[5.1654]])
# yhat=  tensor([[6.8305]], grad_fn=<AddmmBackward0>) y tensor([[4.8548]])
# yhat=  tensor([[6.4170]], grad_fn=<AddmmBackward0>) y tensor([[4.7388]])
# yhat=  tensor([[6.0036]], grad_fn=<AddmmBackward0>) y tensor([[4.3357]])
# yhat=  tensor([[5.5901]], grad_fn=<AddmmBackward0>) y tensor([[4.0743]])
# yhat=  tensor([[5.1766]], grad_fn=<AddmmBackward0>) y tensor([[3.5914]])
# yhat=  tensor([[4.7631]], grad_fn=<AddmmBackward0>) y tensor([[3.2903]])
# yhat=  tensor([[4.3496]], grad_fn=<AddmmBackward0>) y tensor([[3.1274]])
# yhat=  tensor([[3.9361]], grad_fn=<AddmmBackward0>) y tensor([[2.8954]])
# yhat=  tensor([[3.5226]], grad_fn=<AddmmBackward0>) y tensor([[2.4978]])
# yhat=  tensor([[3.1091]], grad_fn=<AddmmBackward0>) y tensor([[2.0837]])
# yhat=  tensor([[2.6956]], grad_fn=<AddmmBackward0>) y tensor([[1.8738]])
# yhat=  tensor([[2.2822]], grad_fn=<AddmmBackward0>) y tensor([[1.5381]])
# yhat=  tensor([[1.8687]], grad_fn=<AddmmBackward0>) y tensor([[1.5037]])
# yhat=  tensor([[1.4552]], grad_fn=<AddmmBackward0>) y tensor([[1.1086]])
# yhat=  tensor([[1.0417]], grad_fn=<AddmmBackward0>) y tensor([[0.8194]])
# yhat=  tensor([[0.6282]], grad_fn=<AddmmBackward0>) y tensor([[0.4945]])
# yhat=  tensor([[0.2147]], grad_fn=<AddmmBackward0>) y tensor([[0.0522]])
# yhat=  tensor([[-0.1988]], grad_fn=<AddmmBackward0>) y tensor([[-0.2140]])
# yhat=  tensor([[-0.6123]], grad_fn=<AddmmBackward0>) y tensor([[-0.5966]])
# yhat=  tensor([[-1.0258]], grad_fn=<AddmmBackward0>) y tensor([[-0.7441]])
# yhat=  tensor([[-1.4392]], grad_fn=<AddmmBackward0>) y tensor([[-1.0324]])
# yhat=  tensor([[-1.8527]], grad_fn=<AddmmBackward0>) y tensor([[-1.4422]])
# yhat=  tensor([[-2.2662]], grad_fn=<AddmmBackward0>) y tensor([[-1.6041]])
# yhat=  tensor([[-2.6797]], grad_fn=<AddmmBackward0>) y tensor([[-2.0537]])
# yhat=  tensor([[-3.0932]], grad_fn=<AddmmBackward0>) y tensor([[-2.2957]])
# yhat=  tensor([[-3.5067]], grad_fn=<AddmmBackward0>) y tensor([[-2.5868]])
# yhat=  tensor([[-3.9202]], grad_fn=<AddmmBackward0>) y tensor([[-2.8850]])
# yhat=  tensor([[-4.3337]], grad_fn=<AddmmBackward0>) y tensor([[-3.1290]])
# yhat=  tensor([[-4.7472]], grad_fn=<AddmmBackward0>) y tensor([[-3.6197]])
# yhat=  tensor([[-5.1606]], grad_fn=<AddmmBackward0>) y tensor([[-3.8153]])
# yhat=  tensor([[-5.5741]], grad_fn=<AddmmBackward0>) y tensor([[-4.1852]])
# yhat=  tensor([[-5.9876]], grad_fn=<AddmmBackward0>) y tensor([[-4.2728]])
# yhat=  tensor([[-6.4011]], grad_fn=<AddmmBackward0>) y tensor([[-4.7995]])
# yhat=  tensor([[-6.8146]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-7.2281]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-7.6416]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.0551]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.4686]], grad_fn=<AddmmBackward0>) y tensor([[20.]])
# yhat=  tensor([[-8.8820]], grad_fn=<AddmmBackward0>) y tensor([[-6.5565]])
# yhat=  tensor([[-9.2955]], grad_fn=<AddmmBackward0>) y tensor([[-6.8723]])
# yhat=  tensor([[-9.7090]], grad_fn=<AddmmBackward0>) y tensor([[-7.2498]])
# yhat=  tensor([[-10.1225]], grad_fn=<AddmmBackward0>) y tensor([[-7.4739]])
# yhat=  tensor([[-10.5360]], grad_fn=<AddmmBackward0>) y tensor([[-7.3923]])
